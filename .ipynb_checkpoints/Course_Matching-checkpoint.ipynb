# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import networkx as nx
from networkx.algorithms.flow import shortest_augmenting_path

# %% [markdown]
# # Part 2

# %%
# Import Room Data
# Each row corresponds to a room in a building.
# The building, room number, capacity of the room, and the school to which the building belongs is listed each row

header_list = ["building", "room_num", "capacity", "school"]
rooms_df = pd.read_csv('data/available_rooms.txt', sep=" ", header=None, names=header_list)
rooms_df.head()
# Out:
#          building room_num  capacity school
# 0       Ames_Hall      218        41     AS
# 1       Ames_Hall      234        60     AS
# 2  Bloomberg_Hall      168        48     AS
# 3  Bloomberg_Hall      172        20     AS
# 4  Bloomberg_Hall      176        34     AS

# %%
# Import Course Data
# Each row corresponds to a potential course. The course number, number of students, school, two potential meeting times are given
# The meeting times are idealized. Each and every meeting lasts for exactly one hour and starts between 9 AM and 4 PM. Thus the last
# two columns have potential values {9, 10, 11, 12, 13, 14, 15, 16} (i.e. 9 AM to 4 PM)

header_list = ["course", "seats", "school", "time_1", "time_2"]
courses_df = pd.read_csv('data/course_data.txt', header=None, names=header_list)
courses_df['course'] = courses_df['course'].apply('{:<07}'.format)
courses_df
# Out:
#       course  seats school  time_1  time_2
# 0    101.001     40     AS      10      13
# 1    101.002     60     AS      11      15
# 2    101.003    100     AS      14      11
# 3    101.004     30     AS      13      15
# 4    101.005     20     AS      12      14
# ..       ...    ...    ...     ...     ...
# 495  500.246     40     EN      13      14
# 496  500.247    212     EN      13      12
# 497  500.248     10     EN      13       9
# 498  500.249     80     EN      15      12
# 499  500.250     40     EN      14      16
#
# [500 rows x 5 columns]

# %%
# Checks the course against the selected building and room number
# returns tuple with first value true if the building belongs to the correct school, the room has enough capacity
# second and third values of tuple are possible times for the course

def compatible(room_index, course_index):
    course_info = courses_df.iloc[course_index]
    room_info = rooms_df.iloc[room_index]

#     print(course_info)
#     print()
#     print(room_info)
#     print()
    
    school_check = (course_info["school"] == room_info["school"])
    capacity_check = (course_info["seats"] <= room_info["capacity"])
    
#     print(school_check)
#     print(capacity_check)
#     print(time_check)
    
    return (school_check and capacity_check, course_info["time_1"], course_info["time_2"])

# Test a random room and course
compatible(4,250)
# Out:
# (False, 13, 12)

# %%
# NOTE: Takes a few seconds to run
# maybe optimize by replacing loops with pandas or networkx functions??

# Create new directed graph
G = nx.DiGraph()

# add courses to graph
G.add_nodes_from(courses_df["course"])

# add room times to graph
for room_index in range(len(rooms_df)):
    room = (rooms_df["building"][room_index], rooms_df["room_num"][room_index])
    for time in range(9, 17):
        G.add_node(room + (time, ))
        
# add compatible edges to bipartite graph
for course_index in range(len(courses_df["course"])):
    for room_index in range(len(rooms_df)):
        room = (rooms_df["building"][room_index], rooms_df["room_num"][room_index])
        course = courses_df["course"][course_index]
        comp, t1, t2 = compatible(room_index, course_index)
            
        if comp:
            G.add_edge(course, room + (t1, ), capacity=1)
            G.add_edge(course, room + (t2, ), capacity=1)
            

# Add edges from source to all courses
G.add_node('s')
for course in (courses_df["course"]):
    G.add_edge('s', course, capacity=1)

# Add edges from all room times to sink
G.add_node('t')
for room_index in range(len(rooms_df)):
    room = (rooms_df["building"][room_index], rooms_df["room_num"][room_index])
    for time in range(9, 17):
        G.add_edge(room + (time, ), 't', capacity=1)

# %%
# calculate max flow and print flow_val
# flow val is the maximum number of courses that can be offered

flow_val, flow_dict = nx.maximum_flow(G, 's', 't', capacity='capacity')
print(flow_val)
# Out:
# 462

# %%
# Print schedule

for course in (courses_df["course"]):
    for room_time in flow_dict[course]:
        if flow_dict[course][room_time] > 0:
            print(course, room_time)
# Out:
# 101.001 ('Bloomberg_Hall', '274', 13)
# 101.004 ('Hodson_Hall', '211', 13)
# 101.005 ('Gilman_Hall', '186', 12)
# 101.006 ('Gilman_Hall', '134', 10)
# 101.008 ('Bloomberg_Hall', '274', 16)
# 101.009 ('Bloomberg_Hall', '274', 15)
# 101.010 ('Gilman_Hall', '132', 13)
# 101.012 ('Hodson_Hall', '203', 13)
# 101.013 ('Gilman_Hall', '219', 11)
# 101.014 ('Croft_Hall', 'G02', 10)
# 101.015 ('Bloomberg_Hall', '272', 9)
# 101.016 ('Ames_Hall', '218', 12)
# 101.017 ('Gilman_Hall', '55', 12)
# 101.018 ('Gilman_Hall', '132', 16)
# 101.019 ('Hodson_Hall', '210', 13)
# 101.020 ('Hodson_Hall', '203', 15)
# 101.021 ('Gilman_Hall', '219', 16)
# 101.022 ('Gilman_Hall', '134', 16)
# 101.024 ('Bloomberg_Hall', '278', 9)
# 101.025 ('Hodson_Hall', '316', 12)
# 101.026 ('Hodson_Hall', '213', 11)
# 101.028 ('Bloomberg_Hall', '176', 12)
# 101.029 ('Gilman_Hall', '377', 13)
# 101.030 ('Bloomberg_Hall', '276', 12)
# 101.031 ('Hodson_Hall', '210', 15)
# 101.032 ('Bloomberg_Hall', '168', 14)
# 101.033 ('Hodson_Hall', '316', 9)
# 101.035 ('Hodson_Hall', '210', 16)
# 101.036 ('Hodson_Hall', '203', 16)
# 101.037 ('Gilman_Hall', '186', 16)
# 101.038 ('Bloomberg_Hall', '276', 11)
# 101.039 ('Gilman_Hall', '50', 15)
# 101.040 ('Gilman_Hall', '17', 12)
# 101.041 ('Bloomberg_Hall', '274', 11)
# 101.042 ('Ames_Hall', '234', 16)
# 101.043 ('Bloomberg_Hall', '272', 13)
# 101.044 ('Croft_Hall', 'B32', 12)
# 101.045 ('Gilman_Hall', '219', 9)
# 101.046 ('Gilman_Hall', '10', 16)
# 101.048 ('Hodson_Hall', '316', 10)
# 101.049 ('Bloomberg_Hall', '278', 12)
# 101.050 ('Hodson_Hall', '213', 12)
# 101.052 ('Hodson_Hall', '216', 14)
# 101.053 ('Gilman_Hall', '119', 11)
# 101.054 ('Bloomberg_Hall', '178', 11)
# 101.056 ('Ames_Hall', '218', 13)
# 101.057 ('Hodson_Hall', '311', 9)
# 101.058 ('Ames_Hall', '234', 12)
# 101.060 ('Gilman_Hall', '119', 15)
# 101.061 ('Bloomberg_Hall', '276', 15)
# 101.062 ('Gilman_Hall', '10', 14)
# 101.063 ('Bloomberg_Hall', '272', 10)
# 101.064 ('Bloomberg_Hall', '168', 15)
# 101.065 ('Gilman_Hall', '55', 9)
# 101.066 ('Hodson_Hall', '213', 14)
# 101.067 ('Hodson_Hall', '210', 14)
# 101.068 ('Hodson_Hall', '211', 14)
# 101.069 ('Gilman_Hall', '219', 13)
# 101.070 ('Bloomberg_Hall', '276', 10)
# 101.072 ('Gilman_Hall', '17', 10)
# 101.073 ('Bloomberg_Hall', '274', 12)
# 101.075 ('Gilman_Hall', '50', 16)
# 101.076 ('Croft_Hall', 'B32', 15)
# 101.077 ('Croft_Hall', 'G02', 11)
# 101.078 ('Gilman_Hall', '134', 13)
# 101.080 ('Bloomberg_Hall', '168', 13)
# 101.081 ('Bloomberg_Hall', '278', 15)
# 101.082 ('Ames_Hall', '234', 14)
# 101.083 ('Hodson_Hall', '110', 16)
# 101.084 ('Croft_Hall', 'G02', 12)
# 101.085 ('Bloomberg_Hall', '178', 10)
# 101.086 ('Gilman_Hall', '134', 9)
# 101.087 ('Hodson_Hall', '210', 10)
# 101.088 ('Bloomberg_Hall', '168', 11)
# 101.089 ('Hodson_Hall', '316', 15)
# 101.091 ('Bloomberg_Hall', '272', 15)
# 101.092 ('Croft_Hall', 'B32', 10)
# 101.093 ('Gilman_Hall', '186', 9)
# 101.094 ('Bloomberg_Hall', '172', 12)
# 101.095 ('Bloomberg_Hall', '272', 14)
# 101.096 ('Ames_Hall', '218', 9)
# 101.097 ('Ames_Hall', '218', 10)
# 101.098 ('Gilman_Hall', '132', 15)
# 101.100 ('Hodson_Hall', '203', 14)
# 101.101 ('Bloomberg_Hall', '276', 9)
# 101.102 ('Bloomberg_Hall', '178', 9)
# 101.104 ('Hodson_Hall', '316', 13)
# 101.105 ('Hodson_Hall', '316', 11)
# 101.106 ('Ames_Hall', '234', 11)
# 101.107 ('Gilman_Hall', '50', 13)
# 101.108 ('Croft_Hall', 'B32', 9)
# 101.109 ('Gilman_Hall', '119', 16)
# 101.110 ('Croft_Hall', 'B32', 11)
# 101.112 ('Hodson_Hall', '311', 11)
# 101.113 ('Hodson_Hall', '311', 10)
# 101.115 ('Hodson_Hall', '210', 12)
# 101.116 ('Hodson_Hall', '203', 9)
# 101.117 ('Gilman_Hall', '119', 9)
# 101.118 ('Gilman_Hall', '119', 12)
# 101.119 ('Gilman_Hall', '50', 9)
# 101.120 ('Hodson_Hall', '316', 14)
# 101.121 ('Gilman_Hall', '17', 9)
# 101.123 ('Gilman_Hall', '50', 10)
# 101.124 ('Croft_Hall', 'G02', 13)
# 101.125 ('Gilman_Hall', '119', 14)
# 101.126 ('Gilman_Hall', '10', 9)
# 101.128 ('Bloomberg_Hall', '274', 10)
# 101.129 ('Hodson_Hall', '311', 13)
# 101.132 ('Gilman_Hall', '119', 10)
# 101.133 ('Gilman_Hall', '186', 14)
# 101.134 ('Croft_Hall', 'G02', 15)
# 101.135 ('Hodson_Hall', '210', 11)
# 101.136 ('Gilman_Hall', '55', 11)
# 101.137 ('Gilman_Hall', '17', 11)
# 101.138 ('Ames_Hall', '234', 10)
# 101.140 ('Croft_Hall', 'G02', 14)
# 101.141 ('Gilman_Hall', '119', 13)
# 101.142 ('Bloomberg_Hall', '276', 14)
# 101.144 ('Hodson_Hall', '311', 16)
# 101.145 ('Hodson_Hall', '311', 15)
# 101.146 ('Hodson_Hall', '213', 15)
# 101.147 ('Gilman_Hall', '50', 11)
# 101.148 ('Hodson_Hall', '211', 9)
# 101.149 ('Bloomberg_Hall', '178', 14)
# 101.150 ('Croft_Hall', 'G02', 9)
# 101.152 ('Bloomberg_Hall', '168', 9)
# 101.153 ('Gilman_Hall', '55', 15)
# 101.154 ('Ames_Hall', '234', 15)
# 101.155 ('Bloomberg_Hall', '272', 11)
# 101.156 ('Bloomberg_Hall', '176', 10)
# 101.157 ('Croft_Hall', 'G02', 16)
# 101.158 ('Bloomberg_Hall', '172', 10)
# 101.160 ('Gilman_Hall', '55', 16)
# 101.161 ('Gilman_Hall', '55', 10)
# 101.162 ('Hodson_Hall', '213', 9)
# 101.163 ('Hodson_Hall', '110', 15)
# 101.164 ('Hodson_Hall', '211', 10)
# 101.165 ('Bloomberg_Hall', '172', 11)
# 101.166 ('Croft_Hall', 'B32', 16)
# 101.167 ('Gilman_Hall', '50', 14)
# 101.168 ('Gilman_Hall', '55', 13)
# 101.169 ('Gilman_Hall', '17', 15)
# 101.170 ('Ames_Hall', '234', 13)
# 101.171 ('Gilman_Hall', '50', 12)
# 101.172 ('Croft_Hall', 'B32', 14)
# 101.173 ('Bloomberg_Hall', '278', 11)
# 101.174 ('Gilman_Hall', '10', 13)
# 101.176 ('Hodson_Hall', '311', 14)
# 101.177 ('Gilman_Hall', '17', 13)
# 101.178 ('Hodson_Hall', '213', 10)
# 101.179 ('Hodson_Hall', '110', 9)
# 101.180 ('Croft_Hall', 'B32', 13)
# 101.181 ('Bloomberg_Hall', '176', 9)
# 101.182 ('Gilman_Hall', '10', 11)
# 101.183 ('Bloomberg_Hall', '272', 12)
# 101.184 ('Gilman_Hall', '55', 14)
# 101.185 ('Gilman_Hall', '17', 16)
# 101.186 ('Gilman_Hall', '132', 9)
# 101.188 ('Bloomberg_Hall', '176', 11)
# 101.189 ('Bloomberg_Hall', '178', 15)
# 101.190 ('Bloomberg_Hall', '276', 16)
# 101.192 ('Gilman_Hall', '17', 14)
# 101.193 ('Bloomberg_Hall', '278', 13)
# 101.194 ('Gilman_Hall', '132', 12)
# 101.195 ('Hodson_Hall', '110', 14)
# 101.196 ('Bloomberg_Hall', '176', 13)
# 101.197 ('Bloomberg_Hall', '178', 12)
# 101.198 ('Bloomberg_Hall', '172', 15)
# 101.200 ('Bloomberg_Hall', '278', 10)
# 101.201 ('Bloomberg_Hall', '168', 12)
# 101.202 ('Hodson_Hall', '213', 16)
# 101.204 ('Bloomberg_Hall', '176', 15)
# 101.205 ('Bloomberg_Hall', '276', 13)
# 101.206 ('Bloomberg_Hall', '178', 16)
# 101.208 ('Hodson_Hall', '316', 16)
# 101.209 ('Bloomberg_Hall', '168', 10)
# 101.210 ('Hodson_Hall', '213', 13)
# 101.211 ('Hodson_Hall', '110', 11)
# 101.212 ('Bloomberg_Hall', '176', 16)
# 101.213 ('Bloomberg_Hall', '172', 9)
# 101.214 ('Bloomberg_Hall', '178', 13)
# 101.215 ('Hodson_Hall', '110', 12)
# 101.216 ('Bloomberg_Hall', '278', 16)
# 101.217 ('Ames_Hall', '218', 11)
# 101.218 ('Ames_Hall', '234', 9)
# 101.219 ('Hodson_Hall', '210', 9)
# 101.220 ('Bloomberg_Hall', '176', 14)
# 101.221 ('Gilman_Hall', '219', 14)
# 101.222 ('Bloomberg_Hall', '172', 16)
# 101.224 ('Bloomberg_Hall', '274', 9)
# 101.225 ('Bloomberg_Hall', '278', 14)
# 101.227 ('Hodson_Hall', '110', 13)
# 101.228 ('Hodson_Hall', '203', 10)
# 101.229 ('Bloomberg_Hall', '172', 13)
# 101.230 ('Bloomberg_Hall', '172', 14)
# 101.231 ('Bloomberg_Hall', '272', 16)
# 101.232 ('Bloomberg_Hall', '274', 14)
# 101.233 ('Bloomberg_Hall', '168', 16)
# 101.234 ('Gilman_Hall', '132', 11)
# 101.236 ('Hodson_Hall', '203', 12)
# 101.237 ('Gilman_Hall', '186', 11)
# 101.238 ('Gilman_Hall', '10', 12)
# 101.240 ('Ames_Hall', '218', 16)
# 101.241 ('Hodson_Hall', '311', 12)
# 101.242 ('Gilman_Hall', '132', 10)
# 101.243 ('Hodson_Hall', '110', 10)
# 101.244 ('Hodson_Hall', '211', 15)
# 101.245 ('Gilman_Hall', '186', 13)
# 101.246 ('Gilman_Hall', '10', 10)
# 101.248 ('Ames_Hall', '218', 15)
# 101.249 ('Ames_Hall', '218', 14)
# 101.250 ('Gilman_Hall', '132', 14)
# 500.001 ('Olin_Hall', '305', 13)
# 500.002 ('Shriver_Hall', '104', 15)
# 500.003 ('Krieger_Hall', 'Laverty_Lounge', 14)
# 500.004 ('Krieger_Hall', '307', 14)
# 500.005 ('Mergenthaler_Hall', '111', 10)
# 500.006 ('Latrobe_Hall', '107', 14)
# 500.007 ('Latrobe_Hall', '107', 10)
# 500.008 ('Mergenthaler_Hall', '111', 9)
# 500.009 ('Maryland_Hall', '110', 9)
# 500.010 ('Shaffer_Hall', '202', 12)
# 500.011 ('Krieger_Hall', '170', 10)
# 500.012 ('Remsen_Hall', '1', 9)
# 500.013 ('Maryland_Hall', '309', 12)
# 500.014 ('Krieger_Hall', '304', 16)
# 500.015 ('Krieger_Hall', '307', 10)
# 500.016 ('Maryland_Hall', '110', 10)
# 500.017 ('Shaffer_Hall', '302', 15)
# 500.018 ('Krieger_Hall', '180', 10)
# 500.019 ('Remsen_Hall', '101', 13)
# 500.020 ('Remsen_Hall', '101', 10)
# 500.021 ('Maryland_Hall', '309', 16)
# 500.022 ('Krieger_Hall', '170', 11)
# 500.023 ('Shaffer_Hall', '2', 12)
# 500.024 ('Shaffer_Hall', '300', 15)
# 500.025 ('Shaffer_Hall', '300', 12)
# 500.026 ('Shaffer_Hall', '303', 13)
# 500.027 ('Shaffer_Hall', '302', 10)
# 500.028 ('Krieger_Hall', '308', 12)
# 500.029 ('Krieger_Hall', '308', 13)
# 500.030 ('Maryland_Hall', '110', 13)
# 500.031 ('Shaffer_Hall', '100', 12)
# 500.032 ('Maryland_Hall', '201', 12)
# 500.033 ('Krieger_Hall', '170', 12)
# 500.034 ('Shaffer_Hall', '301', 10)
# 500.035 ('Krieger_Hall', '309', 12)
# 500.036 ('Krieger_Hall', '304', 12)
# 500.037 ('Krieger_Hall', '307', 13)
# 500.038 ('Shaffer_Hall', '3', 14)
# 500.039 ('Krieger_Hall', '180', 14)
# 500.040 ('Latrobe_Hall', '107', 11)
# 500.041 ('Shaffer_Hall', '304', 12)
# 500.042 ('Remsen_Hall', '101', 14)
# 500.043 ('Shaffer_Hall', '2', 10)
# 500.044 ('Krieger_Hall', '170', 14)
# 500.045 ('Mudd_Hall', '26', 9)
# 500.046 ('Shriver_Hall', '104', 14)
# 500.047 ('Krieger_Hall', '308', 9)
# 500.048 ('Krieger_Hall', '307', 15)
# 500.049 ('Krieger_Hall', '205', 14)
# 500.050 ('Maryland_Hall', '109', 9)
# 500.051 ('Shaffer_Hall', '202', 14)
# 500.052 ('Shaffer_Hall', '2', 14)
# 500.053 ('Shaffer_Hall', '304', 16)
# 500.054 ('Olin_Hall', '305', 12)
# 500.055 ('Shaffer_Hall', '202', 11)
# 500.056 ('Krieger_Hall', 'Laverty_Lounge', 15)
# 500.057 ('Krieger_Hall', '302', 12)
# 500.058 ('Remsen_Hall', '101', 9)
# 500.059 ('Krieger_Hall', '180', 13)
# 500.060 ('Maryland_Hall', '109', 12)
# 500.061 ('Krieger_Hall', '170', 13)
# 500.062 ('Maryland_Hall', '110', 16)
# 500.063 ('Maryland_Hall', '309', 11)
# 500.064 ('Krieger_Hall', '306', 9)
# 500.065 ('Krieger_Hall', '306', 15)
# 500.066 ('Krieger_Hall', '205', 12)
# 500.067 ('Shaffer_Hall', '302', 16)
# 500.068 ('Shaffer_Hall', '2', 11)
# 500.069 ('Shaffer_Hall', '304', 14)
# 500.070 ('Shaffer_Hall', '3', 12)
# 500.071 ('Shaffer_Hall', '202', 13)
# 500.072 ('Olin_Hall', '305', 14)
# 500.073 ('Shaffer_Hall', '303', 9)
# 500.074 ('Krieger_Hall', '309', 16)
# 500.075 ('Krieger_Hall', '302', 16)
# 500.076 ('Krieger_Hall', '300', 9)
# 500.077 ('Shaffer_Hall', '303', 14)
# 500.078 ('Krieger_Hall', '180', 9)
# 500.079 ('Krieger_Hall', '180', 16)
# 500.080 ('Latrobe_Hall', '120', 9)
# 500.081 ('Shaffer_Hall', '301', 11)
# 500.082 ('Remsen_Hall', '1', 16)
# 500.083 ('Maryland_Hall', '201', 16)
# 500.084 ('Krieger_Hall', '308', 14)
# 500.085 ('Krieger_Hall', '307', 9)
# 500.086 ('Remsen_Hall', '1', 15)
# 500.087 ('Shaffer_Hall', '302', 9)
# 500.088 ('Shaffer_Hall', '100', 11)
# 500.089 ('Shaffer_Hall', '303', 16)
# 500.090 ('Shaffer_Hall', '301', 9)
# 500.091 ('Shaffer_Hall', '2', 15)
# 500.092 ('Krieger_Hall', '304', 10)
# 500.093 ('Krieger_Hall', '306', 10)
# 500.094 ('Mergenthaler_Hall', '111', 11)
# 500.095 ('Maryland_Hall', '109', 16)
# 500.096 ('Shaffer_Hall', '100', 15)
# 500.097 ('Shaffer_Hall', '300', 13)
# 500.098 ('Shaffer_Hall', '301', 13)
# 500.099 ('Maryland_Hall', '309', 14)
# 500.100 ('Shaffer_Hall', '300', 11)
# 500.101 ('Shaffer_Hall', '3', 15)
# 500.102 ('Shaffer_Hall', '100', 10)
# 500.103 ('Krieger_Hall', '304', 9)
# 500.104 ('Krieger_Hall', '307', 12)
# 500.105 ('Remsen_Hall', '1', 10)
# 500.106 ('Latrobe_Hall', '120', 12)
# 500.107 ('Latrobe_Hall', '107', 9)
# 500.108 ('Shaffer_Hall', '302', 14)
# 500.109 ('Shaffer_Hall', '304', 9)
# 500.110 ('Krieger_Hall', '205', 13)
# 500.111 ('Maryland_Hall', '309', 10)
# 500.112 ('Krieger_Hall', '306', 12)
# 500.113 ('Krieger_Hall', '307', 11)
# 500.114 ('Shaffer_Hall', '303', 12)
# 500.115 ('Shaffer_Hall', '100', 14)
# 500.116 ('Latrobe_Hall', '120', 10)
# 500.117 ('Shaffer_Hall', '3', 10)
# 500.118 ('Olin_Hall', '305', 11)
# 500.119 ('Maryland_Hall', '309', 15)
# 500.120 ('Krieger_Hall', '306', 14)
# 500.121 ('Krieger_Hall', '302', 9)
# 500.122 ('Shaffer_Hall', '3', 9)
# 500.123 ('Shaffer_Hall', '100', 16)
# 500.124 ('Shaffer_Hall', '202', 9)
# 500.125 ('Olin_Hall', '305', 9)
# 500.126 ('Shaffer_Hall', '301', 14)
# 500.127 ('Maryland_Hall', '201', 10)
# 500.128 ('Remsen_Hall', '101', 15)
# 500.129 ('Remsen_Hall', '1', 14)
# 500.130 ('Krieger_Hall', '309', 11)
# 500.131 ('Krieger_Hall', '300', 12)
# 500.132 ('Krieger_Hall', '306', 13)
# 500.133 ('Shaffer_Hall', '301', 12)
# 500.134 ('Maryland_Hall', '109', 10)
# 500.135 ('Maryland_Hall', '201', 11)
# 500.136 ('Krieger_Hall', '180', 15)
# 500.137 ('Remsen_Hall', '1', 13)
# 500.138 ('Olin_Hall', '305', 10)
# 500.139 ('Maryland_Hall', '109', 15)
# 500.140 ('Krieger_Hall', '304', 13)
# 500.141 ('Krieger_Hall', '306', 11)
# 500.142 ('Shaffer_Hall', '3', 13)
# 500.143 ('Latrobe_Hall', '120', 15)
# 500.144 ('Maryland_Hall', '201', 15)
# 500.145 ('Shaffer_Hall', '3', 11)
# 500.146 ('Mudd_Hall', '26', 15)
# 500.147 ('Shaffer_Hall', '202', 15)
# 500.148 ('Krieger_Hall', '302', 10)
# 500.149 ('Krieger_Hall', '300', 10)
# 500.150 ('Remsen_Hall', '101', 16)
# 500.151 ('Maryland_Hall', '201', 14)
# 500.152 ('Shaffer_Hall', '202', 10)
# 500.153 ('Shaffer_Hall', '300', 16)
# 500.154 ('Mergenthaler_Hall', '111', 13)
# 500.155 ('Maryland_Hall', '201', 9)
# 500.156 ('Mudd_Hall', '26', 10)
# 500.157 ('Shaffer_Hall', '3', 16)
# 500.158 ('Krieger_Hall', '309', 10)
# 500.159 ('Krieger_Hall', '304', 15)
# 500.160 ('Krieger_Hall', '304', 11)
# 500.161 ('Remsen_Hall', '101', 12)
# 500.162 ('Maryland_Hall', '109', 14)
# 500.163 ('Latrobe_Hall', '107', 15)
# 500.164 ('Latrobe_Hall', '107', 12)
# 500.165 ('Remsen_Hall', '101', 11)
# 500.166 ('Mergenthaler_Hall', '111', 16)
# 500.167 ('Maryland_Hall', '309', 13)
# 500.168 ('Krieger_Hall', '300', 11)
# 500.169 ('Krieger_Hall', '300', 16)
# 500.170 ('Mudd_Hall', '26', 16)
# 500.171 ('Latrobe_Hall', '120', 14)
# 500.172 ('Shaffer_Hall', '2', 13)
# 500.173 ('Remsen_Hall', '1', 11)
# 500.174 ('Mudd_Hall', '26', 14)
# 500.175 ('Maryland_Hall', '309', 9)
# 500.176 ('Krieger_Hall', '302', 13)
# 500.177 ('Krieger_Hall', '302', 15)
# 500.178 ('Maryland_Hall', '110', 12)
# 500.179 ('Maryland_Hall', '109', 11)
# 500.180 ('Latrobe_Hall', '120', 16)
# 500.181 ('Krieger_Hall', '170', 9)
# 500.182 ('Olin_Hall', '305', 16)
# 500.183 ('Krieger_Hall', '309', 9)
# 500.184 ('Shaffer_Hall', '304', 10)
# 500.185 ('Mergenthaler_Hall', '111', 15)
# 500.186 ('Krieger_Hall', '309', 14)
# 500.187 ('Krieger_Hall', '308', 15)
# 500.188 ('Krieger_Hall', '108', 9)
# 500.189 ('Maryland_Hall', '110', 14)
# 500.190 ('Shaffer_Hall', '100', 13)
# 500.191 ('Latrobe_Hall', '120', 11)
# 500.192 ('Krieger_Hall', '170', 16)
# 500.193 ('Olin_Hall', '305', 15)
# 500.194 ('Mudd_Hall', '26', 12)
# 500.195 ('Shaffer_Hall', '302', 11)
# 500.196 ('Krieger_Hall', '300', 13)
# 500.197 ('Krieger_Hall', '108', 12)
# 500.198 ('Mergenthaler_Hall', '111', 14)
# 500.199 ('Maryland_Hall', '201', 13)
# 500.200 ('Krieger_Hall', '180', 12)
# 500.201 ('Shaffer_Hall', '300', 10)
# 500.202 ('Shaffer_Hall', '303', 11)
# 500.203 ('Krieger_Hall', '309', 15)
# 500.204 ('Krieger_Hall', '108', 11)
# 500.205 ('Krieger_Hall', '300', 15)
# 500.206 ('Shaffer_Hall', '301', 16)
# 500.207 ('Maryland_Hall', '109', 13)
# 500.208 ('Latrobe_Hall', '120', 13)
# 500.209 ('Shaffer_Hall', '304', 11)
# 500.210 ('Krieger_Hall', '205', 11)
# 500.211 ('Latrobe_Hall', '107', 13)
# 500.212 ('Shaffer_Hall', '304', 13)
# 500.213 ('Krieger_Hall', '205', 10)
# 500.214 ('Shriver_Hall', '104', 12)
# 500.215 ('Krieger_Hall', '304', 14)
# 500.216 ('Krieger_Hall', '108', 16)
# 500.217 ('Mergenthaler_Hall', '111', 12)
# 500.218 ('Krieger_Hall', '170', 15)
# 500.219 ('Krieger_Hall', '180', 11)
# 500.220 ('Latrobe_Hall', '107', 16)
# 500.221 ('Mudd_Hall', '26', 11)
# 500.222 ('Krieger_Hall', '205', 16)
# 500.223 ('Krieger_Hall', '309', 13)
# 500.224 ('Krieger_Hall', '302', 11)
# 500.225 ('Krieger_Hall', '302', 14)
# 500.226 ('Krieger_Hall', '205', 15)
# 500.227 ('Shaffer_Hall', '304', 15)
# 500.228 ('Shaffer_Hall', '2', 9)
# 500.229 ('Remsen_Hall', '1', 12)
# 500.230 ('Shaffer_Hall', '301', 15)
# 500.231 ('Shriver_Hall', '104', 10)
# 500.232 ('Krieger_Hall', '300', 14)
# 500.233 ('Krieger_Hall', '108', 15)
# 500.234 ('Maryland_Hall', '110', 11)
# 500.235 ('Shaffer_Hall', '100', 9)
# 500.236 ('Shaffer_Hall', '302', 12)
# 500.237 ('Shaffer_Hall', '300', 14)
# 500.238 ('Krieger_Hall', '205', 9)
# 500.239 ('Shriver_Hall', '104', 16)
# 500.240 ('Shaffer_Hall', '300', 9)
# 500.241 ('Shaffer_Hall', '303', 10)
# 500.242 ('Shaffer_Hall', '202', 16)
# 500.243 ('Krieger_Hall', '108', 10)
# 500.244 ('Krieger_Hall', '108', 14)
# 500.245 ('Shaffer_Hall', '303', 15)
# 500.246 ('Shaffer_Hall', '302', 13)
# 500.247 ('Mudd_Hall', '26', 13)
# 500.248 ('Krieger_Hall', '108', 13)
# 500.249 ('Maryland_Hall', '110', 15)
# 500.250 ('Shaffer_Hall', '2', 16)
